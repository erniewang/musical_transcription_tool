# %% [raw]
# 1. Getting of rid of frequencies not part of the targeted insturment. For Banju song it seems to be 294 to 784

# %% [raw]
# ffmpeg -i ustadnoorbakesh.wav -af "lowpass=f=184" filtered.wav

# %%
# Out:
# 1824810 16000
