# %%
import sys
print(sys.executable)

import torch
print(torch.__version__)
print(torch.version.cuda)
print(torch.cuda.is_available())

import torch.nn.functional as F
print("torch ok")

import torchaudio
print("torchaudio ok")

import torchcrepe
print("torchcrepe ok")
# Out:
# /home/ernie/miniconda3/envs/crepe/bin/python
# 2.11.0+cu128
# 12.8
# True
# torch ok
# torchaudio ok
# torchcrepe ok

# %%
import torchcrepe
import numpy as np
import soundfile as sf
import torchcodec

# %%
# Load audio
audio, sr = torchcrepe.load.audio("../audio_samples/ustadnoorbakesh.wav")
audio = audio[0]
print("DEBUG: prining out audio",audio.axis)

# Here we'll use a 5 millisecond hop length
hop_length = int(sr / 100.)

# Provide a sensible frequency range for your domain (upper limit is 2006 Hz)
# This would be a reasonable range for speech
fmin = 50
fmax = 1550

# Select a model capacity--one of "tiny" or "full"
model = 'full'

# Choose a device to use for inference
device = 'cuda:0'

# Pick a batch size that doesn't cause memory errors on your gpu
batch_size = 2048

# Compute pitch using first gpu
pitch = torchcrepe.predict(audio,
                           sr,
                           hop_length,
                           fmin,
                           fmax,
                           model,
                           batch_size=batch_size,
                           device=device)

pitch_np = pitch.squeeze().cpu().numpy()

# reconstruct crude sine wave
samples_per_frame = hop_length
audio_out = []

phase = 0.0
for f in pitch_np:
    if f <= 0:
        chunk = np.zeros(samples_per_frame)
    else:
        t = np.arange(samples_per_frame) / sr
        chunk = np.sin(2 * np.pi * f * t + phase)
        phase += 2 * np.pi * f * samples_per_frame / sr
    audio_out.append(chunk)

audio_out = np.concatenate(audio_out)

sf.write("crepe_results/debug_pitch.wav", audio_out, sr)
# Out:
# DEBUG: prining out audio tensor([0., 0., 0.,  ..., 0., 0., 0.])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 24
#      21 batch_size = 2048
#      23 # Compute pitch using first gpu
# ---> 24 pitch = torchcrepe.predict(audio,
#      25                            sr,
#      26                            hop_length,
#      27                            fmin,
#      28                            fmax,
#      29                            model,
#      30                            batch_size=batch_size,
#      31                            device=device)
#      33 pitch_np = pitch.squeeze().cpu().numpy()
#      35 # reconstruct crude sine wave
#
# File ~/miniconda3/envs/crepe/lib/python3.10/site-packages/torchcrepe/core.py:117, in predict(audio, sample_rate, hop_length, fmin, fmax, model, decoder, return_harmonicity, return_periodicity, batch_size, device, pad)
#     108 with torch.no_grad():
#     109
#     110     # Preprocess audio
#     111     generator = preprocess(audio,
#     112                            sample_rate,
#     113                            hop_length,
#     114                            batch_size,
#     115                            device,
#     116                            pad)
# --> 117     for frames in generator:
#     118
#     119         # Infer independent probabilities for each pitch bin
#     120         probabilities = infer(frames, model, device, embed=False)
#     122         # shape=(batch, 360, time / hop_length)
#
# File ~/miniconda3/envs/crepe/lib/python3.10/site-packages/torchcrepe/core.py:656, in preprocess(audio, sample_rate, hop_length, batch_size, device, pad)
#     654 # Resample
#     655 if sample_rate != SAMPLE_RATE:
# --> 656     audio = resample(audio, sample_rate)
#     657     hop_length = int(hop_length * SAMPLE_RATE / sample_rate)
#     659 # Get total number of frames
#     660
#     661 # Maybe pad
#
# File ~/miniconda3/envs/crepe/lib/python3.10/site-packages/torchcrepe/core.py:731, in resample(audio, sample_rate)
#     728 device = audio.device
#     730 # Convert to numpy
# --> 731 audio = audio.detach().cpu().numpy().squeeze(0)
#     733 # Resample
#     734 # We have to use resampy if we want numbers to match Crepe
#     735 audio = resampy.resample(audio, sample_rate, SAMPLE_RATE)
#
# ValueError: cannot select an axis to squeeze out which has size not equal to one
